# %% [markdown]
# # Applied Data Science Capstone final project
#
# This notebook is my final project for the Applied Data Science Capstone course from Coursera. In this notebook, a location problem will be studied.

# %% [markdown]
# # Problem description
#
# One of the major natural sites of São Paulo – Brazil is the Ibirapuera park. The park has over 100 hectares and it is in Moema neighborhood, in the center-south of São Paulo. The park is one of the most famous parks in Latin America, attracting millions of visitors a year.
#
# Due the large number of visitors the park receives every day, an investor would like to know if the surrounding of the park would be a good place to build his restaurant. To answer this question, the investor will open his restaurant if there is a region, next to the park, with not too many competitors. If such area is available, he also wants to know if it is better to open an Italian, a vegetarian or a Japanese restaurant, the types of food he already invests in.

# %% [markdown]
# 1. First, let's import the modules for the analysis.

# %%
# libraries for displaying images
from IPython.display import Image 
from IPython.core.display import HTML 

# library to handle requests
import requests 

# tranforming json file into a pandas dataframe library
from pandas.io.json import json_normalize

#If the folium library is not installed, download it
#!conda install -c conda-forge folium=0.5.0 --yes
# !pip install folium
import folium # plotting library
# Out:
# Collecting folium
#   Downloading https://files.pythonhosted.org/packages/72/ff/004bfe344150a064e558cb2aedeaa02ecbf75e60e148a55a9198f0c41765/folium-0.10.0-py2.py3-none-any.whl (91kB)
#      |████████████████████████████████| 92kB 13.5MB/s eta 0:00:01
# Requirement already satisfied: jinja2>=2.9 in /opt/conda/envs/Python36/lib/python3.6/site-packages (from folium) (2.10)
# Collecting branca>=0.3.0 (from folium)
#   Downloading https://files.pythonhosted.org/packages/63/36/1c93318e9653f4e414a2e0c3b98fc898b4970e939afeedeee6075dd3b703/branca-0.3.1-py3-none-any.whl
# Requirement already satisfied: numpy in /opt/conda/envs/Python36/lib/python3.6/site-packages (from folium) (1.15.4)
# Requirement already satisfied: requests in /opt/conda/envs/Python36/lib/python3.6/site-packages (from folium) (2.21.0)
# Requirement already satisfied: MarkupSafe>=0.23 in /opt/conda/envs/Python36/lib/python3.6/site-packages (from jinja2>=2.9->folium) (1.1.0)
# Requirement already satisfied: six in /opt/conda/envs/Python36/lib/python3.6/site-packages (from branca>=0.3.0->folium) (1.12.0)
# Requirement already satisfied: idna<2.9,>=2.5 in /opt/conda/envs/Python36/lib/python3.6/site-packages (from requests->folium) (2.8)
# Requirement already satisfied: urllib3<1.25,>=1.21.1 in /opt/conda/envs/Python36/lib/python3.6/site-packages (from requests->folium) (1.24.1)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/conda/envs/Python36/lib/python3.6/site-packages (from requests->folium) (2019.9.11)
# Requirement already satisfied: chardet<3.1.0,>=3.0.2 in /opt/conda/envs/Python36/lib/python3.6/site-packages (from requests->folium) (3.0.4)
# Installing collected packages: branca, folium
# Successfully installed branca-0.3.1 folium-0.10.0

# %% [markdown]
# # Data collection
#
# To answer the question proposed in the business problem, some location information will be required. First, it is necessary the latitude and longitude of the park. Due to its size, the center of the park will be used as reference for its location. The latitude and longitude were already identified using Google maps and is -23.588375, -46.658258. With the latitude and longitude of the park, the closest food venues will be identified through Foursquare API, with a radius of 2500 meters. This large radius was chosen due the size of the park. With a 2500 meter-radius, we will assure that at least a five-block radius surrounding the park will be considered when looking for food venues.
#
# After collecting the data, the data will be reviewed and cleaned. A cluster analysis will be performed using the latitude and longitude of the venues to identify regions with lower density of food venues. The clusters will be plotted through using folium to make the visualization easier. If there is a low density region, the categories of the venues will be reviewed to see what are the most popular food types and a recommendation of a type of restaurant will be made based on the other types of restaurants available in the region selected.

# %% [markdown]
# 2. Connect to Foursquare API (each developer should use their own ID).

# %%
CLIENT_ID = 'F5HJDHZEFG4JTDOGREYAUHRZH1ZGY1MYDWJCMZEDLPJ3DVHF' # your Foursquare ID
CLIENT_SECRET = '4K334FEQ4Y3UQBGWHJDWN1QIFRXWWXDQINHB0QYP4DJWDUPP' # your Foursquare Secret
VERSION = '20191005'
LIMIT = 100

# %% [markdown]
# 3. Requesting the data for Foursquare.
#
# Observation:
#
# A) Since we are investigating food places, the search query will be food.
#
# B) The minimum radius will be 2500 meter due the size of the park. With a 2500 radius, we will assure that at least a five-block radius surrounding the park will be considered when looking for food venues.
#
# C) The latitude and longitude of the center of the park were identified through Google Maps.

# %%
#First we define what we are looking for
search_query = 'Food'

#Then we define the radious
radius = 2500

#Get the latitude and longitude Ibirapuera park 
lat = -23.588375
long =  -46.658258

#Finaly we set the url for our search
url = 'https://api.foursquare.com/v2/venues/search?client_id={}&client_secret={}&ll={},{}&v={}&query={}&radius={}&limit={}'.format(CLIENT_ID, CLIENT_SECRET, lat, long, VERSION, search_query, radius, LIMIT)

# %% [markdown]
# 4. Requesting the reults.

# %%
results = requests.get(url).json()
results
# Out:
# {'meta': {'code': 200, 'requestId': '5da1cc1666fc65002c825ab2'},
#  'response': {'venues': [{'id': '54528c3f498ea48fc80daa59',
#     'name': 'Goa Food Truck (TCC)',
#     'location': {'address': 'Rua José Antônio Coelho, 879',
#      'lat': -23.58184,
#      'lng': -46.649849,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': -23.58184,
#        'lng': -46.649849}],
#      'distance': 1124,
#      'cc': 'BR',
#      'city': 'São Paulo',
#      'state': 'SP',
#      'country': 'Brasil',
#      'formattedAddress': ['Rua José Antônio Coelho, 879',
#       'São Paulo, SP',
#       'Brasil']},
#     'categories': [{'id': '4bf58dd8d48988d1d3941735',
#       'name': 'Vegetarian / Vegan Restaurant',
#       'pluralName': 'Vegetarian / Vegan Restaurants',
#       'shortName': 'Vegetarian / Vegan',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/vegetarian_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1570884630',
#     'hasPerk': False},
#    {'id': '4bf30cc1706e20a1fdc8a798',
#     'name': 'Fit Food',
#     'location': {'address': 'Reebok Sports Club',
#      'lat': -23.59553296145961,
#      'lng': -46.68434094467216,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': -23.59553296145961,
#        'lng': -46.68434094467216}],
#      'distance': 2777,
#      'postalCode': '04551-000',
#      'cc': 'BR',
#      'city': 'São Paulo',
#      'state': 'SP',
#      'country': 'Brasil',
#      'formattedAddress': ['Reebok Sports Club',
#       'São Paulo, SP',
#       '04551-000',
#       'Brasil']},
#     'categories': [{'id': '4bf58dd8d48988d1c4941735',
#       'name': 'Restaurant',
#       'pluralName': 'Restaurants',
#       'shortName': 'Restaurant',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/default_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1570884630',
#     'hasPerk': False},
#    {'id': '4c548403b426ef3b53d8838a',
#     'name': 'Irashai Japanese Food',
#     'location': {'address': 'R. Dr. Fausto Ferraz, 28',
#      'crossStreet': 'R. Carlos Sampaio',
#      'lat': -23.56639167123151,
#      'lng': -46.645370242524955,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': -23.56639167123151,
#        'lng': -46.645370242524955}],
#      'distance': 2778,
#      'postalCode': '01333-030',
#      'cc': 'BR',
#      'neighborhood': 'Bela Vista',
#      'city': 'São Paulo',
#      'state': 'SP',
#      'country': 'Brasil',
#      'formattedAddress': ['R. Dr. Fausto Ferraz, 28 (R. Carlos Sampaio)',
#       'São Paulo, SP',
#       '01333-030',
#       'Brasil']},
#     'categories': [{'id': '4bf58dd8d48988d1d2941735',
#       'name': 'Sushi Restaurant',
#       'pluralName': 'Sushi Restaurants',
#       'shortName': 'Sushi',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/sushi_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1570884630',
#     'hasPerk': False},
#    {'id': '4c3ca244933b0f470856e421',
#     'name': 'Quality Food',
#     'location': {'address': 'R. Peixoto Gomide, 1052',
#      'lat': -23.562156370562008,
#      'lng': -46.65871307095927,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': -23.562156370562008,
#        'lng': -46.65871307095927}],
#      'distance': 2918,
#      'postalCode': '01409-000',
#      'cc': 'BR',
#      'city': 'São Paulo',
#      'state': 'SP',
#      'country': 'Brasil',
#      'formattedAddress': ['R. Peixoto Gomide, 1052',
#       'São Paulo, SP',
#       '01409-000',
#       'Brasil']},
#     'categories': [{'id': '4bf58dd8d48988d16b941735',
#       'name': 'Brazilian Restaurant',
#       'pluralName': 'Brazilian Restaurants',
#       'shortName': 'Brazilian',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/argentinian_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1570884630',
#     'hasPerk': False},
#    {'id': '520ba1f711d2955c26da4960',
#     'name': 'Fit Food',
#     'location': {'address': 'Bodytech',
#      'lat': -23.58745054043526,
#      'lng': -46.67778433456282,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': -23.58745054043526,
#        'lng': -46.67778433456282}],
#      'distance': 1994,
#      'postalCode': '04542-000',
#      'cc': 'BR',
#      'city': 'São Paulo',
#      'state': 'SP',
#      'country': 'Brasil',
#      'formattedAddress': ['Bodytech', 'São Paulo, SP', '04542-000', 'Brasil']},
#     'categories': [{'id': '4bf58dd8d48988d1c4941735',
#       'name': 'Restaurant',
#       'pluralName': 'Restaurants',
#       'shortName': 'Restaurant',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/default_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1570884630',
#     'hasPerk': False},
#    {'id': '4fe31839e4b0675f958bbfed',
#     'name': 'Desenvolvimento Food - NCR Colibri Brasil',
#     'location': {'address': 'Rua Coronel Artur De Godoi, 16 - Vila Mariana',
#      'lat': -23.584187549254004,
#      'lng': -46.6396182805388,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': -23.584187549254004,
#        'lng': -46.6396182805388}],
#      'distance': 1957,
#      'postalCode': '04018-050',
#      'cc': 'BR',
#      'city': 'São Paulo',
#      'state': 'SP',
#      'country': 'Brasil',
#      'formattedAddress': ['Rua Coronel Artur De Godoi, 16 - Vila Mariana',
#       'São Paulo, SP',
#       '04018-050',
#       'Brasil']},
#     'categories': [{'id': '4bf58dd8d48988d125941735',
#       'name': 'Tech Startup',
#       'pluralName': 'Tech Startups',
#       'shortName': 'Tech Startup',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/technology_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1570884630',
#     'hasPerk': False},
#    {'id': '59a9aa63d8fe7a0d1368ee55',
#     'name': 'Vila Olímpia Food Hall',
#     'location': {'address': 'R. Tenerife, 74',
#      'lat': -23.596512,
#      'lng': -46.688254,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': -23.596512,
#        'lng': -46.688254}],
#      'distance': 3191,
#      'postalCode': '04548-040',
#      'cc': 'BR',
#      'city': 'São Paulo',
#      'state': 'SP',
#      'country': 'Brasil',
#      'formattedAddress': ['R. Tenerife, 74',
#       'São Paulo, SP',
#       '04548-040',
#       'Brasil']},
#     'categories': [{'id': '53e0feef498e5aac066fd8a9',
#       'name': 'Street Food Gathering',
#       'pluralName': 'Street Food Gatherings',
#       'shortName': 'Street Food Gathering',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/streetfood_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1570884630',
#     'hasPerk': False},
#    {'id': '4c2a215f9fb5d13a9e329c57',
#     'name': "Pança's Fast Food",
#     'location': {'address': 'R. Correia Dias, 370',
#      'lat': -23.576486,
#      'lng': -46.639803,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': -23.576486,
#        'lng': -46.639803}],
#      'distance': 2301,
#      'postalCode': '04104-001',
#      'cc': 'BR',
#      'city': 'São Paulo',
#      'state': 'SP',
#      'country': 'Brasil',
#      'formattedAddress': ['R. Correia Dias, 370',
#       'São Paulo, SP',
#       '04104-001',
#       'Brasil']},
#     'categories': [{'id': '4bf58dd8d48988d16b941735',
#       'name': 'Brazilian Restaurant',
#       'pluralName': 'Brazilian Restaurants',
#       'shortName': 'Brazilian',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/argentinian_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1570884630',
#     'hasPerk': False},
#    {'id': '54302711498e92eb4a152e79',
#     'name': 'Komê Japonese Food',
#     'location': {'address': 'Rua São Miguel',
#      'crossStreet': 'Rua Frei Caneca',
#      'lat': -23.555284893559485,
#      'lng': -46.65453049475009,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': -23.555284893559485,
#        'lng': -46.65453049475009}],
#      'distance': 3703,
#      'cc': 'BR',
#      'city': 'São Paulo',
#      'state': 'SP',
#      'country': 'Brasil',
#      'formattedAddress': ['Rua São Miguel (Rua Frei Caneca)',
#       'São Paulo, SP',
#       'Brasil']},
#     'categories': [{'id': '4bf58dd8d48988d1d2941735',
#       'name': 'Sushi Restaurant',
#       'pluralName': 'Sushi Restaurants',
#       'shortName': 'Sushi',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/sushi_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1570884630',
#     'hasPerk': False},
#    {'id': '4b92f3e2f964a520f92934e3',
#     'name': 'Sapporo Japanese Food',
#     'location': {'address': 'Pç. N.Sa. Aparecida, 114',
#      'lat': -23.603776773816076,
#      'lng': -46.66083644840485,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': -23.603776773816076,
#        'lng': -46.66083644840485}],
#      'distance': 1734,
#      'postalCode': '04075-010',
#      'cc': 'BR',
#      'city': 'São Paulo',
#      'state': 'SP',
#      'country': 'Brasil',
#      'formattedAddress': ['Pç. N.Sa. Aparecida, 114',
#       'São Paulo, SP',
#       '04075-010',
#       'Brasil']},
#     'categories': [{'id': '4bf58dd8d48988d111941735',
#       'name': 'Japanese Restaurant',
#       'pluralName': 'Japanese Restaurants',
#       'shortName': 'Japanese',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/japanese_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1570884630',
#     'hasPerk': False},
#    {'id': '591b62a4b9ac384466c171c7',
#     'name': 'NaturALL Fit - Healthy Food & Supplements',
#     'location': {'address': '240 Rua Urussuí',
#      'lat': -23.604378,
#      'lng': -46.640018,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': -23.604378,
#        'lng': -46.640018}],
#      'distance': 2575,
#      'postalCode': '04542-051',
#      'cc': 'BR',
#      'city': 'São Paulo',
#      'state': 'SP',
#      'country': 'Brasil',
#      'formattedAddress': ['240 Rua Urussuí',
#       'São Paulo, SP',
#       '04542-051',
#       'Brasil']},
#     'categories': [{'id': '4bf58dd8d48988d1f9941735',
#       'name': 'Food & Drink Shop',
#       'pluralName': 'Food & Drink Shops',
#       'shortName': 'Food & Drink',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/foodanddrink_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1570884630',
#     'hasPerk': False},
#    {'id': '4e45c115e4cd9d94fb195d67',
#     'name': 'Taste It Food & Lounge',
#     'location': {'address': 'R. Joinville, 515',
#      'crossStreet': 'Pullman Hotel',
#      'lat': -23.582427759201718,
#      'lng': -46.65025892066275,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': -23.582427759201718,
#        'lng': -46.65025892066275}],
#      'distance': 1050,
#      'postalCode': '04008-011',
#      'cc': 'BR',
#      'city': 'São Paulo',
#      'state': 'SP',
#      'country': 'Brasil',
#      'formattedAddress': ['R. Joinville, 515 (Pullman Hotel)',
#       'São Paulo, SP',
#       '04008-011',
#       'Brasil']},
#     'categories': [{'id': '4bf58dd8d48988d1c4941735',
#       'name': 'Restaurant',
#       'pluralName': 'Restaurants',
#       'shortName': 'Restaurant',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/default_',
#        'suffix': '.png'},
#       'primary': True}],
#     'venuePage': {'id': '223078648'},
#     'referralId': 'v-1570884630',
#     'hasPerk': False},
#    {'id': '582e68789f25833ffdb2d467',
#     'name': 'Polemikka Beer & Food',
#     'location': {'address': 'Rua Nelson Fernandes, 393',
#      'crossStreet': 'Rua General Manuel Vargas',
#      'lat': -23.612554190180685,
#      'lng': -46.66409611701965,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': -23.612554190180685,
#        'lng': -46.66409611701965}],
#      'distance': 2756,
#      'postalCode': '04084-001',
#      'cc': 'BR',
#      'city': 'São Paulo',
#      'state': 'SP',
#      'country': 'Brasil',
#      'formattedAddress': ['Rua Nelson Fernandes, 393 (Rua General Manuel Vargas)',
#       'São Paulo, SP',
#       '04084-001',
#       'Brasil']},
#     'categories': [{'id': '56aa371ce4b08b9a8d57356c',
#       'name': 'Beer Bar',
#       'pluralName': 'Beer Bars',
#       'shortName': 'Beer Bar',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/nightlife/pub_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1570884630',
#     'hasPerk': False},
#    {'id': '593c0b98f0b490219469f5cf',
#     'name': 'Hirota Food Express',
#     'location': {'address': 'R. Pedro de Toledo, 591',
#      'lat': -23.598579298452666,
#      'lng': -46.642552614212036,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': -23.598579298452666,
#        'lng': -46.642552614212036}],
#      'distance': 1963,
#      'postalCode': '04039-031',
#      'cc': 'BR',
#      'neighborhood': 'Vila Clementino',
#      'city': 'São Paulo',
#      'state': 'SP',
#      'country': 'Brasil',
#      'formattedAddress': ['R. Pedro de Toledo, 591',
#       'São Paulo, SP',
#       '04039-031',
#       'Brasil']},
#     'categories': [{'id': '4d954b0ea243a5684a65b473',
#       'name': 'Convenience Store',
#       'pluralName': 'Convenience Stores',
#       'shortName': 'Convenience Store',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/conveniencestore_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1570884630',
#     'hasPerk': False},
#    {'id': '53efadb1498e52a63d3968c9',
#     'name': 'Olea Italian Food Truck',
#     'location': {'address': 'R. Simão Álvares 114',
#      'lat': -23.56330021316964,
#      'lng': -46.667669564588344,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': -23.56330021316964,
#        'lng': -46.667669564588344}],
#      'distance': 2951,
#      'cc': 'BR',
#      'city': 'São Paulo',
#      'state': 'SP',
#      'country': 'Brasil',
#      'formattedAddress': ['R. Simão Álvares 114', 'São Paulo, SP', 'Brasil']},
#     'categories': [{'id': '4bf58dd8d48988d1cb941735',
#       'name': 'Food Truck',
#       'pluralName': 'Food Trucks',
#       'shortName': 'Food Truck',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/streetfood_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1570884630',
#     'hasPerk': False},
#    {'id': '54525d51498e4ae259d259d0',
#     'name': 'EF Food Park',
#     'location': {'address': 'Av. Brigadeiro Luís Antônio, 4701',
#      'lat': -23.58342500149973,
#      'lng': -46.65913608310543,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': -23.58342500149973,
#        'lng': -46.65913608310543}],
#      'distance': 558,
#      'cc': 'BR',
#      'city': 'São Paulo',
#      'state': 'SP',
#      'country': 'Brasil',
#      'formattedAddress': ['Av. Brigadeiro Luís Antônio, 4701',
#       'São Paulo, SP',
#       'Brasil']},
#     'categories': [{'id': '4bf58dd8d48988d1cb941735',
#       'name': 'Food Truck',
#       'pluralName': 'Food Trucks',
#       'shortName': 'Food Truck',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/streetfood_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1570884630',
#     'hasPerk': False},
#    {'id': '59d6649d69e77b16737ea5ff',
#     'name': 'Furikake Food',
#     'location': {'address': 'Rua França Pinto 466',
#      'lat': -23.58721134094985,
#      'lng': -46.6409052102601,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': -23.58721134094985,
#        'lng': -46.6409052102601}],
#      'distance': 1775,
#      'postalCode': '04016-002',
#      'cc': 'BR',
#      'city': 'São Paulo',
#      'state': 'SP',
#      'country': 'Brasil',
#      'formattedAddress': ['Rua França Pinto 466',
#       'São Paulo, SP',
#       '04016-002',
#       'Brasil']},
#     'categories': [{'id': '4bf58dd8d48988d111941735',
#       'name': 'Japanese Restaurant',
#       'pluralName': 'Japanese Restaurants',
#       'shortName': 'Japanese',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/japanese_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1570884630',
#     'hasPerk': False},
#    {'id': '4f71f690771671e6d7606813',
#     'name': 'food truck quatro',
#     'location': {'address': 'avenida brigadeiro faria lima, 1300',
#      'lat': -23.580474541825104,
#      'lng': -46.66075308947441,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': -23.580474541825104,
#        'lng': -46.66075308947441}],
#      'distance': 915,
#      'cc': 'BR',
#      'city': 'São Paulo',
#      'state': 'SP',
#      'country': 'Brasil',
#      'formattedAddress': ['avenida brigadeiro faria lima, 1300',
#       'São Paulo, SP',
#       'Brasil']},
#     'categories': [{'id': '4bf58dd8d48988d1cb941735',
#       'name': 'Food Truck',
#       'pluralName': 'Food Trucks',
#       'shortName': 'Food Truck',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/streetfood_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1570884630',
#     'hasPerk': False},
#    {'id': '4d49cbf59544a0934a432ce7',
#     'name': 'Shigueru Japanese Food',
#     'location': {'address': 'R. Leopoldo Couto de Magalhaes Júnior, 275',
#      'lat': -23.58695109553043,
#      'lng': -46.67561046373718,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': -23.58695109553043,
#        'lng': -46.67561046373718}],
#      'distance': 1777,
#      'cc': 'BR',
#      'city': 'São Paulo',
#      'state': 'SP',
#      'country': 'Brasil',
#      'formattedAddress': ['R. Leopoldo Couto de Magalhaes Júnior, 275',
#       'São Paulo, SP',
#       'Brasil']},
#     'categories': [{'id': '4bf58dd8d48988d111941735',
#       'name': 'Japanese Restaurant',
#       'pluralName': 'Japanese Restaurants',
#       'shortName': 'Japanese',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/japanese_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1570884630',
#     'hasPerk': False},
#    {'id': '5acdf3c56fa81f479105ddf4',
#     'name': "Hale I'a Hawaiian Fish Food",
#     'location': {'address': 'R. Prof. Atílio Innocenti, 693',
#      'lat': -23.59376172010065,
#      'lng': -46.67937397956848,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': -23.59376172010065,
#        'lng': -46.67937397956848}],
#      'distance': 2236,
#      'postalCode': '04538-001',
#      'cc': 'BR',
#      'city': 'São Paulo',
#      'state': 'SP',
#      'country': 'Brasil',
#      'formattedAddress': ['R. Prof. Atílio Innocenti, 693',
#       'São Paulo, SP',
#       '04538-001',
#       'Brasil']},
#     'categories': [{'id': '52e81612bcbc57f1066b79fe',
#       'name': 'Hawaiian Restaurant',
#       'pluralName': 'Hawaiian Restaurants',
#       'shortName': 'Hawaiian',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/default_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1570884630',
#     'hasPerk': False},
#    {'id': '5796aa43498e4f6d74a7e2eb',
#     'name': 'Kimchi Food Truck',
#     'location': {'address': 'R. Maj. Maragliano, 356',
#      'crossStreet': 'R. Cap. Cavalcanti',
#      'lat': -23.58595455942457,
#      'lng': -46.64261544749139,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': -23.58595455942457,
#        'lng': -46.64261544749139}],
#      'distance': 1618,
#      'postalCode': '04017-000',
#      'cc': 'BR',
#      'city': 'São Paulo',
#      'state': 'SP',
#      'country': 'Brasil',
#      'formattedAddress': ['R. Maj. Maragliano, 356 (R. Cap. Cavalcanti)',
#       'São Paulo, SP',
#       '04017-000',
#       'Brasil']},
#     'categories': [{'id': '4bf58dd8d48988d1cb941735',
#       'name': 'Food Truck',
#       'pluralName': 'Food Trucks',
#       'shortName': 'Food Truck',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/streetfood_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1570884630',
#     'hasPerk': False},
#    {'id': '54f4b40b498eed5faaf9838a',
#     'name': 'Bronx - Street Food Shop',
#     'location': {'address': 'R. Inhambu, 683',
#      'lat': -23.600997676831263,
#      'lng': -46.66812784397034,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': -23.600997676831263,
#        'lng': -46.66812784397034}],
#      'distance': 1728,
#      'postalCode': '04520-013',
#      'cc': 'BR',
#      'city': 'São Paulo',
#      'state': 'SP',
#      'country': 'Brasil',
#      'formattedAddress': ['R. Inhambu, 683',
#       'São Paulo, SP',
#       '04520-013',
#       'Brasil']},
#     'categories': [{'id': '4bf58dd8d48988d1c5941735',
#       'name': 'Sandwich Place',
#       'pluralName': 'Sandwich Places',
#       'shortName': 'Sandwiches',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/deli_',
#        'suffix': '.png'},
#       'primary': True}],
#     'venuePage': {'id': '121613175'},
#     'referralId': 'v-1570884630',
#     'hasPerk': False},
#    {'id': '50cc9085e4b06fef21b4bc04',
#     'name': 'Suzaku Japanese Food',
#     'location': {'address': 'R. Joaquim Távora, 1235',
#      'crossStreet': 'R. Rio Grande',
#      'lat': -23.58734967559272,
#      'lng': -46.64422688566692,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': -23.58734967559272,
#        'lng': -46.64422688566692}],
#      'distance': 1435,
#      'postalCode': '04015-002',
#      'cc': 'BR',
#      'city': 'São Paulo',
#      'state': 'SP',
#      'country': 'Brasil',
#      'formattedAddress': ['R. Joaquim Távora, 1235 (R. Rio Grande)',
#       'São Paulo, SP',
#       '04015-002',
#       'Brasil']},
#     'categories': [{'id': '4bf58dd8d48988d111941735',
#       'name': 'Japanese Restaurant',
#       'pluralName': 'Japanese Restaurants',
#       'shortName': 'Japanese',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/japanese_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1570884630',
#     'hasPerk': False},
#    {'id': '56aeab51498ee7b0fc24acd1',
#     'name': 'Food Factory',
#     'location': {'address': 'R. José Antônio Coelho, 593 - Vila Mariana',
#      'lat': -23.580946,
#      'lng': -46.64621,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': -23.580946,
#        'lng': -46.64621}],
#      'distance': 1481,
#      'postalCode': '04011-061',
#      'cc': 'BR',
#      'city': 'São Paulo',
#      'state': 'SP',
#      'country': 'Brasil',
#      'formattedAddress': ['R. José Antônio Coelho, 593 - Vila Mariana',
#       'São Paulo, SP',
#       '04011-061',
#       'Brasil']},
#     'categories': [{'id': '4bf58dd8d48988d174941735',
#       'name': 'Coworking Space',
#       'pluralName': 'Coworking Spaces',
#       'shortName': 'Coworking Space',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/office_coworkingspace_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1570884630',
#     'hasPerk': False},
#    {'id': '545401fa498e9def910a7c79',
#     'name': 'food truck da rua pelotas',
#     'location': {'address': 'Rua Pelotas',
#      'lat': -23.582181877159133,
#      'lng': -46.64562693332632,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': -23.582181877159133,
#        'lng': -46.64562693332632}],
#      'distance': 1461,
#      'postalCode': '04012-000',
#      'cc': 'BR',
#      'city': 'São Paulo',
#      'state': 'SP',
#      'country': 'Brasil',
#      'formattedAddress': ['Rua Pelotas',
#       'São Paulo, SP',
#       '04012-000',
#       'Brasil']},
#     'categories': [{'id': '4bf58dd8d48988d1d1941735',
#       'name': 'Noodle House',
#       'pluralName': 'Noodle Houses',
#       'shortName': 'Noodles',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/ramen_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1570884630',
#     'hasPerk': False},
#    {'id': '5799302e498edc15fa4f09ce',
#     'name': 'Na Cumbuca Food Truck',
#     'location': {'address': 'Rua Pirapora, 98',
#      'crossStreet': 'Rua Tutóia',
#      'lat': -23.58119585678459,
#      'lng': -46.65101766586304,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': -23.58119585678459,
#        'lng': -46.65101766586304}],
#      'distance': 1088,
#      'postalCode': '04008-060',
#      'cc': 'BR',
#      'city': 'São Paulo',
#      'state': 'SP',
#      'country': 'Brasil',
#      'formattedAddress': ['Rua Pirapora, 98 (Rua Tutóia)',
#       'São Paulo, SP',
#       '04008-060',
#       'Brasil']},
#     'categories': [{'id': '4bf58dd8d48988d1cb941735',
#       'name': 'Food Truck',
#       'pluralName': 'Food Trucks',
#       'shortName': 'Food Truck',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/streetfood_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1570884630',
#     'hasPerk': False},
#    {'id': '566042f4498e288f3c09f09d',
#     'name': 'Mambo Supermercado',
#     'location': {'address': 'R. Canário, 408',
#      'lat': -23.599691328059897,
#      'lng': -46.6655316366217,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': -23.599691328059897,
#        'lng': -46.6655316366217}],
#      'distance': 1462,
#      'postalCode': '04521-001',
#      'cc': 'BR',
#      'city': 'São Paulo',
#      'state': 'SP',
#      'country': 'Brasil',
#      'formattedAddress': ['R. Canário, 408',
#       'São Paulo, SP',
#       '04521-001',
#       'Brasil']},
#     'categories': [{'id': '52f2ab2ebcbc57f1066b8b46',
#       'name': 'Supermarket',
#       'pluralName': 'Supermarkets',
#       'shortName': 'Supermarket',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/food_grocery_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1570884630',
#     'hasPerk': False},
#    {'id': '57a65fdc498eb1432d034702',
#     'name': 'Ibira Food Square',
#     'location': {'address': 'R. Joinville, 186',
#      'lat': -23.580212561636397,
#      'lng': -46.65212273597717,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': -23.580212561636397,
#        'lng': -46.65212273597717}],
#      'distance': 1103,
#      'postalCode': '04008-010',
#      'cc': 'BR',
#      'city': 'São Paulo',
#      'state': 'SP',
#      'country': 'Brasil',
#      'formattedAddress': ['R. Joinville, 186',
#       'São Paulo, SP',
#       '04008-010',
#       'Brasil']},
#     'categories': [{'id': '53e0feef498e5aac066fd8a9',
#       'name': 'Street Food Gathering',
#       'pluralName': 'Street Food Gatherings',
#       'shortName': 'Street Food Gathering',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/streetfood_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1570884630',
#     'hasPerk': False},
#    {'id': '571ff3c6498e4c84ce848aac',
#     'name': 'Buzina Food Truck',
#     'location': {'address': 'R. Pirapora, 98',
#      'lat': -23.57876359620542,
#      'lng': -46.6524988912028,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': -23.57876359620542,
#        'lng': -46.6524988912028}],
#      'distance': 1220,
#      'cc': 'BR',
#      'city': 'São Paulo',
#      'state': 'SP',
#      'country': 'Brasil',
#      'formattedAddress': ['R. Pirapora, 98', 'São Paulo, SP', 'Brasil']},
#     'categories': [{'id': '4bf58dd8d48988d1cb941735',
#       'name': 'Food Truck',
#       'pluralName': 'Food Trucks',
#       'shortName': 'Food Truck',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/streetfood_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1570884630',
#     'hasPerk': False},
#    {'id': '54d78484498ead5140a5fe48',
#     'name': 'Good Food Brasil',
#     'location': {'address': 'Rua Serra de Japi, 1451',
#      'lat': -23.600316808971538,
#      'lng': -46.656147352002044,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': -23.600316808971538,
#        'lng': -46.656147352002044}],
#      'distance': 1346,
#      'cc': 'BR',
#      'city': 'São Paulo',
#      'state': 'SP',
#      'country': 'Brasil',
#      'formattedAddress': ['Rua Serra de Japi, 1451',
#       'São Paulo, SP',
#       'Brasil']},
#     'categories': [{'id': '4bf58dd8d48988d1cb941735',
#       'name': 'Food Truck',
#       'pluralName': 'Food Trucks',
#       'shortName': 'Food Truck',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/streetfood_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1570884630',
#     'hasPerk': False},
#    {'id': '5d2753c4256bfd0023851643',
#     'name': 'Gorilla Food Truck',
#     'location': {'address': 'Rua Tutoia, 1157',
#      'lat': -23.580042,
#      'lng': -46.648803,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': -23.580042,
#        'lng': -46.648803}],
#      'distance': 1338,
#      'postalCode': '04007-060',
#      'cc': 'BR',
#      'city': 'São Paulo',
#      'state': 'SP',
#      'country': 'Brasil',
#      'formattedAddress': ['Rua Tutoia, 1157',
#       'São Paulo, SP',
#       '04007-060',
#       'Brasil']},
#     'categories': [{'id': '4bf58dd8d48988d1cb941735',
#       'name': 'Food Truck',
#       'pluralName': 'Food Trucks',
#       'shortName': 'Food Truck',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/streetfood_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1570884630',
#     'hasPerk': False},
#    {'id': '57001831498e5cff02b4a6a0',
#     'name': 'Food One',
#     'location': {'lat': -23.604309309101073,
#      'lng': -46.66295946832037,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': -23.604309309101073,
#        'lng': -46.66295946832037}],
#      'distance': 1837,
#      'cc': 'BR',
#      'country': 'Brasil',
#      'formattedAddress': ['Brasil']},
#     'categories': [{'id': '4bf58dd8d48988d1cb941735',
#       'name': 'Food Truck',
#       'pluralName': 'Food Trucks',
#       'shortName': 'Food Truck',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/streetfood_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1570884630',
#     'hasPerk': False},
#    {'id': '55fc2a34498ed7002c08a75e',
#     'name': "Vitrolla's Food Truck",
#     'location': {'address': 'Av. Brigadeiro Luís Antônio, 3751',
#      'lat': -23.576085540402342,
#      'lng': -46.657566269862365,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': -23.576085540402342,
#        'lng': -46.657566269862365}],
#      'distance': 1369,
#      'cc': 'BR',
#      'country': 'Brasil',
#      'formattedAddress': ['Av. Brigadeiro Luís Antônio, 3751', 'Brasil']},
#     'categories': [{'id': '4bf58dd8d48988d1cb941735',
#       'name': 'Food Truck',
#       'pluralName': 'Food Trucks',
#       'shortName': 'Food Truck',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/streetfood_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1570884630',
#     'hasPerk': False},
#    {'id': '56eb0257cd10c4efdf7baa24',
#     'name': 'Hirota Food Express',
#     'location': {'address': 'Av. Paulista, 726',
#      'lat': -23.566475158330242,
#      'lng': -46.650105714797974,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': -23.566475158330242,
#        'lng': -46.650105714797974}],
#      'distance': 2575,
#      'postalCode': '01310-100',
#      'cc': 'BR',
#      'city': 'São Paulo',
#      'state': 'SP',
#      'country': 'Brasil',
#      'formattedAddress': ['Av. Paulista, 726',
#       'São Paulo, SP',
#       '01310-100',
#       'Brasil']},
#     'categories': [{'id': '4d954b0ea243a5684a65b473',
#       'name': 'Convenience Store',
#       'pluralName': 'Convenience Stores',
#       'shortName': 'Convenience Store',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/conveniencestore_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1570884630',
#     'hasPerk': False},
#    {'id': '541c6990498ee38559911cc3',
#     'name': 'Food Truck Festival B4i',
#     'location': {'address': 'R. Groenladia, 848',
#      'lat': -23.574858550550804,
#      'lng': -46.670291191884665,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': -23.574858550550804,
#        'lng': -46.670291191884665}],
#      'distance': 1941,
#      'cc': 'BR',
#      'country': 'Brasil',
#      'formattedAddress': ['R. Groenladia, 848', 'Brasil']},
#     'categories': [{'id': '4bf58dd8d48988d1cb941735',
#       'name': 'Food Truck',
#       'pluralName': 'Food Trucks',
#       'shortName': 'Food Truck',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/streetfood_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1570884630',
#     'hasPerk': False},
#    {'id': '5058ae4de4b02049c1ed7626',
#     'name': 'Kebebariak Casual Food',
#     'location': {'lat': -23.584044,
#      'lng': -46.671783,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': -23.584044,
#        'lng': -46.671783}],
#      'distance': 1461,
#      'cc': 'BR',
#      'country': 'Brasil',
#      'formattedAddress': ['Brasil']},
#     'categories': [{'id': '4bf58dd8d48988d10b941735',
#       'name': 'Falafel Restaurant',
#       'pluralName': 'Falafel Restaurants',
#       'shortName': 'Falafel',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/falafel_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1570884630',
#     'hasPerk': False},
#    {'id': '543306ca498e1a4f90a35455',
#     'name': 'Food Trucker',
#     'location': {'address': 'Rua Dr. Bacelar, 1043',
#      'lat': -23.603858054047738,
#      'lng': -46.64830867538655,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': -23.603858054047738,
#        'lng': -46.64830867538655}],
#      'distance': 2000,
#      'cc': 'BR',
#      'city': 'São Paulo',
#      'state': 'SP',
#      'country': 'Brasil',
#      'formattedAddress': ['Rua Dr. Bacelar, 1043', 'São Paulo, SP', 'Brasil']},
#     'categories': [{'id': '4bf58dd8d48988d16e941735',
#       'name': 'Fast Food Restaurant',
#       'pluralName': 'Fast Food Restaurants',
#       'shortName': 'Fast Food',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/fastfood_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1570884630',
#     'hasPerk': False},
#    {'id': '5397233a498e82b504c1c53a',
#     'name': 'HUB-Food Art & Lounge',
#     'location': {'address': 'Rua Olimpiadas 205',
#      'crossStreet': 'Rua Quata',
#      'lat': -23.59569275503985,
#      'lng': -46.68455199310622,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': -23.59569275503985,
#        'lng': -46.68455199310622}],
#      'distance': 2803,
#      'postalCode': '04551-000',
#      'cc': 'BR',
#      'city': 'São Paulo',
#      'state': 'SP',
#      'country': 'Brasil',
#      'formattedAddress': ['Rua Olimpiadas 205 (Rua Quata)',
#       'São Paulo, SP',
#       '04551-000',
#       'Brasil']},
#     'categories': [{'id': '4bf58dd8d48988d121941735',
#       'name': 'Lounge',
#       'pluralName': 'Lounges',
#       'shortName': 'Lounge',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/nightlife/default_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1570884630',
#     'hasPerk': False},
#    {'id': '5aa2ceebc0cacb329102052a',
#     'name': 'Food Park Jardim Pamplona',
#     'location': {'address': 'Jardim Pamplona',
#      'crossStreet': 'Piso 3 - Faria Lima',
#      'lat': -23.5705168771572,
#      'lng': -46.66112422943115,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': -23.5705168771572,
#        'lng': -46.66112422943115}],
#      'distance': 2009,
#      'postalCode': '01405-002',
#      'cc': 'BR',
#      'city': 'São Paulo',
#      'state': 'SP',
#      'country': 'Brasil',
#      'formattedAddress': ['Jardim Pamplona (Piso 3 - Faria Lima)',
#       'São Paulo, SP',
#       '01405-002',
#       'Brasil']},
#     'categories': [{'id': '53e0feef498e5aac066fd8a9',
#       'name': 'Street Food Gathering',
#       'pluralName': 'Street Food Gatherings',
#       'shortName': 'Street Food Gathering',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/streetfood_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1570884630',
#     'hasPerk': False},
#    {'id': '542ed1ab498e7edd4dd10a7b',
#     'name': '4Brothers Food Truck',
#     'location': {'address': 'Av. Brig. Faria Lima, 1306',
#      'lat': -23.581567262793573,
#      'lng': -46.64563164627912,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': -23.581567262793573,
#        'lng': -46.64563164627912}],
#      'distance': 1494,
#      'cc': 'BR',
#      'city': 'São Paulo',
#      'state': 'SP',
#      'country': 'Brasil',
#      'formattedAddress': ['Av. Brig. Faria Lima, 1306',
#       'São Paulo, SP',
#       'Brasil']},
#     'categories': [{'id': '4bf58dd8d48988d1cb941735',
#       'name': 'Food Truck',
#       'pluralName': 'Food Trucks',
#       'shortName': 'Food Truck',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/streetfood_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1570884630',
#     'hasPerk': False},
#    {'id': '55a67b22498e4921f223280f',
#     'name': 'Da Praia Food Truck',
#     'location': {'lat': -23.58592668930397,
#      'lng': -46.643892596913,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': -23.58592668930397,
#        'lng': -46.643892596913}],
#      'distance': 1490,
#      'cc': 'BR',
#      'country': 'Brasil',
#      'formattedAddress': ['Brasil']},
#     'categories': [{'id': '4bf58dd8d48988d1cb941735',
#       'name': 'Food Truck',
#       'pluralName': 'Food Trucks',
#       'shortName': 'Food Truck',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/streetfood_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1570884630',
#     'hasPerk': False},
#    {'id': '584c1b25109dfe7d5cb20e73',
#     'name': 'Food Truck Alameda Rio Claro',
#     'location': {'lat': -23.562272741048183,
#      'lng': -46.654775612599316,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': -23.562272741048183,
#        'lng': -46.654775612599316}],
#      'distance': 2927,
#      'postalCode': '01332-010',
#      'cc': 'BR',
#      'city': 'São Paulo',
#      'state': 'SP',
#      'country': 'Brasil',
#      'formattedAddress': ['São Paulo, SP', '01332-010', 'Brasil']},
#     'categories': [{'id': '4bf58dd8d48988d1cb941735',
#       'name': 'Food Truck',
#       'pluralName': 'Food Trucks',
#       'shortName': 'Food Truck',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/streetfood_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1570884630',
#     'hasPerk': False},
#    {'id': '5037b298e0e2a2e8d6831879',
#     'name': 'Móbile - Cantina Brasil (Food Express)',
#     'location': {'address': 'Rua Araguari, 177',
#      'crossStreet': 'Rua Diogo Jácome',
#      'lat': -23.598264686491355,
#      'lng': -46.66884899139404,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': -23.598264686491355,
#        'lng': -46.66884899139404}],
#      'distance': 1542,
#      'postalCode': '04514-041',
#      'cc': 'BR',
#      'city': 'São Paulo',
#      'state': 'SP',
#      'country': 'Brasil',
#      'formattedAddress': ['Rua Araguari, 177 (Rua Diogo Jácome)',
#       'São Paulo, SP',
#       '04514-041',
#       'Brasil']},
#     'categories': [{'id': '4bf58dd8d48988d1c4941735',
#       'name': 'Restaurant',
#       'pluralName': 'Restaurants',
#       'shortName': 'Restaurant',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/default_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1570884630',
#     'hasPerk': False},
#    {'id': '54653f53498e75af09128be2',
#     'name': 'EHMASSA! Food',
#     'location': {'address': 'Rua Álvaro Alvim 140',
#      'lat': -23.58973300726492,
#      'lng': -46.6409432888031,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': -23.58973300726492,
#        'lng': -46.6409432888031}],
#      'distance': 1772,
#      'postalCode': '04018-002',
#      'cc': 'BR',
#      'city': 'São Paulo',
#      'state': 'SP',
#      'country': 'Brasil',
#      'formattedAddress': ['Rua Álvaro Alvim 140',
#       'São Paulo, SP',
#       '04018-002',
#       'Brasil']},
#     'categories': [{'id': '4bf58dd8d48988d110941735',
#       'name': 'Italian Restaurant',
#       'pluralName': 'Italian Restaurants',
#       'shortName': 'Italian',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/italian_',
#        'suffix': '.png'},
#       'primary': True}],
#     'venuePage': {'id': '537545082'},
#     'referralId': 'v-1570884630',
#     'hasPerk': False},
#    {'id': '5790318d498e4beaff60eff2',
#     'name': 'Tirolez Food Truck',
#     'location': {'lat': -23.587656787599485,
#      'lng': -46.642544757518635,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': -23.587656787599485,
#        'lng': -46.642544757518635}],
#      'distance': 1605,
#      'cc': 'BR',
#      'country': 'Brasil',
#      'formattedAddress': ['Brasil']},
#     'categories': [{'id': '4bf58dd8d48988d1cb941735',
#       'name': 'Food Truck',
#       'pluralName': 'Food Trucks',
#       'shortName': 'Food Truck',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/streetfood_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1570884630',
#     'hasPerk': False},
#    {'id': '59cd08c4112c6c23742b0585',
#     'name': 'Hirota Food Express',
#     'location': {'address': 'R. Bandeira Paulista, 464',
#      'lat': -23.583595090721694,
#      'lng': -46.67599278978405,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': -23.583595090721694,
#        'lng': -46.67599278978405}],
#      'distance': 1885,
#      'postalCode': '04532-001',
#      'cc': 'BR',
#      'city': 'São Paulo',
#      'state': 'SP',
#      'country': 'Brasil',
#      'formattedAddress': ['R. Bandeira Paulista, 464',
#       'São Paulo, SP',
#       '04532-001',
#       'Brasil']},
#     'categories': [{'id': '4d954b0ea243a5684a65b473',
#       'name': 'Convenience Store',
#       'pluralName': 'Convenience Stores',
#       'shortName': 'Convenience Store',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/conveniencestore_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1570884630',
#     'hasPerk': False},
#    {'id': '5479ded2498ec5945ac23a77',
#     'name': 'Óticas Carol Moema & Food Truck Doritos',
#     'location': {'address': 'Rua Canário, 1.149',
#      'lat': -23.60035791409851,
#      'lng': -46.6675752640109,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': -23.60035791409851,
#        'lng': -46.6675752640109}],
#      'distance': 1637,
#      'cc': 'BR',
#      'city': 'São Paulo',
#      'state': 'SP',
#      'country': 'Brasil',
#      'formattedAddress': ['Rua Canário, 1.149', 'São Paulo, SP', 'Brasil']},
#     'categories': [{'id': '4bf58dd8d48988d1c7941735',
#       'name': 'Snack Place',
#       'pluralName': 'Snack Places',
#       'shortName': 'Snacks',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/snacks_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1570884630',
#     'hasPerk': False},
#    {'id': '573dccf9498e5a50926b5ada',
#     'name': 'Na Cumbuca Food Truck',
#     'location': {'crossStreet': 'Av. João de Sousa Dias, 371',
#      'lat': -23.602718274401095,
#      'lng': -46.66202127395295,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': -23.602718274401095,
#        'lng': -46.66202127395295}],
#      'distance': 1642,
#      'cc': 'BR',
#      'state': 'São Paulo',
#      'country': 'Brasil',
#      'formattedAddress': ['Av. João de Sousa Dias, 371',
#       'São Paulo',
#       'Brasil']},
#     'categories': [{'id': '4bf58dd8d48988d1cb941735',
#       'name': 'Food Truck',
#       'pluralName': 'Food Trucks',
#       'shortName': 'Food Truck',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/streetfood_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1570884630',
#     'hasPerk': False},
#    {'id': '59da7a5a79f6c7660ff0cb6a',
#     'name': "Food Truck's Hortifruti",
#     'location': {'address': 'Rua Tuim, 915',
#      'lat': -23.60398,
#      'lng': -46.672277,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': -23.60398,
#        'lng': -46.672277}],
#      'distance': 2250,
#      'cc': 'BR',
#      'city': 'São Paulo',
#      'state': 'SP',
#      'country': 'Brasil',
#      'formattedAddress': ['Rua Tuim, 915', 'São Paulo, SP', 'Brasil']},
#     'categories': [{'id': '4bf58dd8d48988d1cb941735',
#       'name': 'Food Truck',
#       'pluralName': 'Food Trucks',
#       'shortName': 'Food Truck',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/streetfood_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1570884630',
#     'hasPerk': False},
#    {'id': '56a3b55c498ebcb9ae9202df',
#     'name': 'Libano Food Truck',
#     'location': {'address': 'Praça Nossa Senhora Aparecida',
#      'lat': -23.603272,
#      'lng': -46.660531,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': -23.603272,
#        'lng': -46.660531}],
#      'distance': 1674,
#      'cc': 'BR',
#      'city': 'São Paulo',
#      'state': 'SP',
#      'country': 'Brasil',
#      'formattedAddress': ['Praça Nossa Senhora Aparecida',
#       'São Paulo, SP',
#       'Brasil']},
#     'categories': [{'id': '4bf58dd8d48988d1cb941735',
#       'name': 'Food Truck',
#       'pluralName': 'Food Trucks',
#       'shortName': 'Food Truck',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/streetfood_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1570884630',
#     'hasPerk': False}]}}

# %% [markdown]
# 5. Assigning the data to a dataframe.

# %%
# assign relevant part of JSON to venues
venues = results['response']['venues']

# tranform venues into a dataframe
food_venues = json_normalize(venues)
food_venues.head()
# Out:
#                                           categories  hasPerk  \
# 0  [{'id': '4bf58dd8d48988d1d3941735', 'name': 'V...    False
# 1  [{'id': '4bf58dd8d48988d1c4941735', 'name': 'R...    False
# 2  [{'id': '4bf58dd8d48988d1d2941735', 'name': 'S...    False
# 3  [{'id': '4bf58dd8d48988d16b941735', 'name': 'B...    False
# 4  [{'id': '4bf58dd8d48988d1c4941735', 'name': 'R...    False
#
#                          id              location.address location.cc  \
# 0  54528c3f498ea48fc80daa59  Rua José Antônio Coelho, 879          BR
# 1  4bf30cc1706e20a1fdc8a798            Reebok Sports Club          BR
# 2  4c548403b426ef3b53d8838a      R. Dr. Fausto Ferraz, 28          BR
# 3  4c3ca244933b0f470856e421       R. Peixoto Gomide, 1052          BR
# 4  520ba1f711d2955c26da4960                      Bodytech          BR
#
#   location.city location.country location.crossStreet  location.distance  \
# 0     São Paulo           Brasil                  NaN               1124
# 1     São Paulo           Brasil                  NaN               2777
# 2     São Paulo           Brasil    R. Carlos Sampaio               2778
# 3     São Paulo           Brasil                  NaN               2918
# 4     São Paulo           Brasil                  NaN               1994
#
#                            location.formattedAddress  \
# 0  [Rua José Antônio Coelho, 879, São Paulo, SP, ...
# 1  [Reebok Sports Club, São Paulo, SP, 04551-000,...
# 2  [R. Dr. Fausto Ferraz, 28 (R. Carlos Sampaio),...
# 3  [R. Peixoto Gomide, 1052, São Paulo, SP, 01409...
# 4       [Bodytech, São Paulo, SP, 04542-000, Brasil]
#
#                              location.labeledLatLngs  location.lat  \
# 0  [{'label': 'display', 'lat': -23.58184, 'lng':...    -23.581840
# 1  [{'label': 'display', 'lat': -23.5955329614596...    -23.595533
# 2  [{'label': 'display', 'lat': -23.5663916712315...    -23.566392
# 3  [{'label': 'display', 'lat': -23.5621563705620...    -23.562156
# 4  [{'label': 'display', 'lat': -23.5874505404352...    -23.587451
#
#    location.lng location.neighborhood location.postalCode location.state  \
# 0    -46.649849                   NaN                 NaN             SP
# 1    -46.684341                   NaN           04551-000             SP
# 2    -46.645370            Bela Vista           01333-030             SP
# 3    -46.658713                   NaN           01409-000             SP
# 4    -46.677784                   NaN           04542-000             SP
#
#                     name    referralId venuePage.id
# 0   Goa Food Truck (TCC)  v-1570884630          NaN
# 1               Fit Food  v-1570884630          NaN
# 2  Irashai Japanese Food  v-1570884630          NaN
# 3           Quality Food  v-1570884630          NaN
# 4               Fit Food  v-1570884630          NaN

# %% [markdown]
# 6. Filtering the data and updating the dataframe.

# %%
# keep only columns that include venue name, and anything that is associated with location
filtered_columns = ['name', 'categories'] + [col for col in food_venues.columns if col.startswith('location.')] + ['id']
food_filtered = food_venues.loc[:, filtered_columns]

# function that extracts the category of the venue
def get_category_type(row):
    try:
        categories_list = row['categories']
    except:
        categories_list = row['venue.categories']
        
    if len(categories_list) == 0:
        return None
    else:
        return categories_list[0]['name']

# filter the category for each row
food_filtered['categories'] = food_filtered.apply(get_category_type, axis=1)

# clean column names by keeping only last term
food_filtered.columns = [column.split('.')[-1] for column in food_filtered.columns]

food_filtered.head()
# Out:
#                     name                     categories  \
# 0   Goa Food Truck (TCC)  Vegetarian / Vegan Restaurant
# 1               Fit Food                     Restaurant
# 2  Irashai Japanese Food               Sushi Restaurant
# 3           Quality Food           Brazilian Restaurant
# 4               Fit Food                     Restaurant
#
#                         address  cc       city country        crossStreet  \
# 0  Rua José Antônio Coelho, 879  BR  São Paulo  Brasil                NaN
# 1            Reebok Sports Club  BR  São Paulo  Brasil                NaN
# 2      R. Dr. Fausto Ferraz, 28  BR  São Paulo  Brasil  R. Carlos Sampaio
# 3       R. Peixoto Gomide, 1052  BR  São Paulo  Brasil                NaN
# 4                      Bodytech  BR  São Paulo  Brasil                NaN
#
#    distance                                   formattedAddress  \
# 0      1124  [Rua José Antônio Coelho, 879, São Paulo, SP, ...
# 1      2777  [Reebok Sports Club, São Paulo, SP, 04551-000,...
# 2      2778  [R. Dr. Fausto Ferraz, 28 (R. Carlos Sampaio),...
# 3      2918  [R. Peixoto Gomide, 1052, São Paulo, SP, 01409...
# 4      1994       [Bodytech, São Paulo, SP, 04542-000, Brasil]
#
#                                       labeledLatLngs        lat        lng  \
# 0  [{'label': 'display', 'lat': -23.58184, 'lng':... -23.581840 -46.649849
# 1  [{'label': 'display', 'lat': -23.5955329614596... -23.595533 -46.684341
# 2  [{'label': 'display', 'lat': -23.5663916712315... -23.566392 -46.645370
# 3  [{'label': 'display', 'lat': -23.5621563705620... -23.562156 -46.658713
# 4  [{'label': 'display', 'lat': -23.5874505404352... -23.587451 -46.677784
#
#   neighborhood postalCode state                        id
# 0          NaN        NaN    SP  54528c3f498ea48fc80daa59
# 1          NaN  04551-000    SP  4bf30cc1706e20a1fdc8a798
# 2   Bela Vista  01333-030    SP  4c548403b426ef3b53d8838a
# 3          NaN  01409-000    SP  4c3ca244933b0f470856e421
# 4          NaN  04542-000    SP  520ba1f711d2955c26da4960

# %% [markdown]
# Now the ID's and names are easier to interpret. When we look to the categories of the venues, some of them are related to food, but are not restaurants. The venue 6, for example, is a tech statup.
#
# Therefore, it is necessary to clean the dataframe.

# %% [markdown]
# 7. Data cleaning.
#
# To clean the framework, the categories column will be used. If the words "restaurant", "cafe" or "Food" are not presented in the categories, it is likely that the venue will not be a competitor to our investor, so this entries will be droped.

# %%
#Creating an empty list that will keep the venues to be droped
not_restaurant = []

#Checking if the words 'restaurant', 'food' or 'cafe' are not in the column categories
for i in range(len(food_filtered['categories'])):
    if 'Restaurant' not in food_filtered['categories'].iloc[i]:
        if 'Food' not in food_filtered['categories'].iloc[i]:
            if 'Cafe' not in food_filtered['categories'].iloc[i]:
                not_restaurant.append(i)

#Dropping the row identified in the for loop
food_filtered.drop(food_filtered.index[[not_restaurant]], axis=0, inplace=True)
food_filtered.head(10)
# Out:
# /opt/conda/envs/Python36/lib/python3.6/site-packages/pandas/core/indexes/base.py:3968: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   result = getitem(key)
#                                          name                     categories  \
# 0                        Goa Food Truck (TCC)  Vegetarian / Vegan Restaurant
# 1                                    Fit Food                     Restaurant
# 2                       Irashai Japanese Food               Sushi Restaurant
# 3                                Quality Food           Brazilian Restaurant
# 4                                    Fit Food                     Restaurant
# 6                      Vila Olímpia Food Hall          Street Food Gathering
# 7                           Pança's Fast Food           Brazilian Restaurant
# 8                          Komê Japonese Food               Sushi Restaurant
# 9                       Sapporo Japanese Food            Japanese Restaurant
# 10  NaturALL Fit - Healthy Food & Supplements              Food & Drink Shop
#
#                          address  cc       city country        crossStreet  \
# 0   Rua José Antônio Coelho, 879  BR  São Paulo  Brasil                NaN
# 1             Reebok Sports Club  BR  São Paulo  Brasil                NaN
# 2       R. Dr. Fausto Ferraz, 28  BR  São Paulo  Brasil  R. Carlos Sampaio
# 3        R. Peixoto Gomide, 1052  BR  São Paulo  Brasil                NaN
# 4                       Bodytech  BR  São Paulo  Brasil                NaN
# 6                R. Tenerife, 74  BR  São Paulo  Brasil                NaN
# 7           R. Correia Dias, 370  BR  São Paulo  Brasil                NaN
# 8                 Rua São Miguel  BR  São Paulo  Brasil    Rua Frei Caneca
# 9       Pç. N.Sa. Aparecida, 114  BR  São Paulo  Brasil                NaN
# 10               240 Rua Urussuí  BR  São Paulo  Brasil                NaN
#
#     distance                                   formattedAddress  \
# 0       1124  [Rua José Antônio Coelho, 879, São Paulo, SP, ...
# 1       2777  [Reebok Sports Club, São Paulo, SP, 04551-000,...
# 2       2778  [R. Dr. Fausto Ferraz, 28 (R. Carlos Sampaio),...
# 3       2918  [R. Peixoto Gomide, 1052, São Paulo, SP, 01409...
# 4       1994       [Bodytech, São Paulo, SP, 04542-000, Brasil]
# 6       3191  [R. Tenerife, 74, São Paulo, SP, 04548-040, Br...
# 7       2301  [R. Correia Dias, 370, São Paulo, SP, 04104-00...
# 8       3703  [Rua São Miguel (Rua Frei Caneca), São Paulo, ...
# 9       1734  [Pç. N.Sa. Aparecida, 114, São Paulo, SP, 0407...
# 10      2575  [240 Rua Urussuí, São Paulo, SP, 04542-051, Br...
#
#                                        labeledLatLngs        lat        lng  \
# 0   [{'label': 'display', 'lat': -23.58184, 'lng':... -23.581840 -46.649849
# 1   [{'label': 'display', 'lat': -23.5955329614596... -23.595533 -46.684341
# 2   [{'label': 'display', 'lat': -23.5663916712315... -23.566392 -46.645370
# 3   [{'label': 'display', 'lat': -23.5621563705620... -23.562156 -46.658713
# 4   [{'label': 'display', 'lat': -23.5874505404352... -23.587451 -46.677784
# 6   [{'label': 'display', 'lat': -23.596512, 'lng'... -23.596512 -46.688254
# 7   [{'label': 'display', 'lat': -23.576486, 'lng'... -23.576486 -46.639803
# 8   [{'label': 'display', 'lat': -23.5552848935594... -23.555285 -46.654530
# 9   [{'label': 'display', 'lat': -23.6037767738160... -23.603777 -46.660836
# 10  [{'label': 'display', 'lat': -23.604378, 'lng'... -23.604378 -46.640018
#
#    neighborhood postalCode state                        id
# 0           NaN        NaN    SP  54528c3f498ea48fc80daa59
# 1           NaN  04551-000    SP  4bf30cc1706e20a1fdc8a798
# 2    Bela Vista  01333-030    SP  4c548403b426ef3b53d8838a
# 3           NaN  01409-000    SP  4c3ca244933b0f470856e421
# 4           NaN  04542-000    SP  520ba1f711d2955c26da4960
# 6           NaN  04548-040    SP  59a9aa63d8fe7a0d1368ee55
# 7           NaN  04104-001    SP  4c2a215f9fb5d13a9e329c57
# 8           NaN        NaN    SP  54302711498e92eb4a152e79
# 9           NaN  04075-010    SP  4b92f3e2f964a520f92934e3
# 10          NaN  04542-051    SP  591b62a4b9ac384466c171c7

# %% [markdown]
# As we can see, the row 6 and all other rows that didn't contained the words 'Restaurant', 'Cafe' or 'Food' we droped, therefore, the dataframe is clean.

# %% [markdown]
# 8. Explore the location of the venues using their latitude and longitude.
#
# To explore such locations, let's use the folium module to plot them.

# %%
venues_map = folium.Map(location=[lat, long], zoom_start=14) # generate map centred around Downtown Toronto

# add a red circle marker to represent Downtown Toronto
folium.vector_layers.CircleMarker(
    location = [lat, long],
    radius=10,
    color='red',
    fill = True,
    fill_color = 'red',
    fill_opacity = 0.6
).add_to(venues_map)

# add the Italian restaurants as blue circle markers
for lat, lng, label in zip(food_filtered.lat, food_filtered.lng, food_filtered.categories):
    folium.vector_layers.CircleMarker(
        [lat, lng],
        radius=5,
        color='blue',
        popup=label,
        fill = True,
        fill_color='blue',
        fill_opacity=0.6
    ).add_to(venues_map)

# display map
venues_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# We can already see that there are some regions with higher concentration of restaurants. To further explore such regions, let's group the venues using K-means.

# %% [markdown]
# # Research method
#
# To further analyze the food venues in the region, a cluster analysis will be used to group the venues based on their latitude and longitude. To perform the clustering, Kmeans will be used. Kmeans was chosen because it is a simple algorithm to be implemented and will have a good performance considering the number of data points.
#
# After forming the clusters, the region that doesn’t present a cluster, or presents the cluster with the lowest density, will be chosen to be the potential location. With the potential location in mind, the surrounding venues of the location will be evaluated. If there is a region with no venues, the closest cluster will be used to choose the appropriate restaurant. Since our investor wants to open a restaurant with fewer competitors, the categories of the venue will be reviewed to see how many Japanese, Italian and vegetarian restaurants are in the region, the type of restaurant that has fewer direct competitors will be chosen.

# %% [markdown]
# 9. Cluster analysis.

# %% [markdown]
# First, we need to load an extra module.

# %%
from sklearn.cluster import KMeans

# %% [markdown]
# Second, let's use the latitude and longitude of the venues to cluster them.
#
# Since we have a large radius, let's use seven clusters for the analysis.

# %%
#Initializing k-means with seven clusters
k_means = KMeans(init="k-means++", n_clusters=7, n_init=12)

#Grouping the location based on latitude and longitude
k_means.fit(food_filtered[['lat','lng']])

#Get the label of the cluster
k_means_labels = k_means.labels_
k_means_labels
# Out:
# array([2, 0, 4, 4, 0, 0, 6, 4, 5, 1, 2, 3, 2, 6, 2, 0, 0, 6, 6, 2, 2, 2,
#        5, 2, 5, 2, 3, 0, 1, 3, 6, 6, 4, 5, 6, 6, 5, 5, 5], dtype=int32)

# %% [markdown]
# Third, let's add a column in the dataframe to store the cluster labels

# %%
food_filtered['cluster'] = k_means_labels
food_filtered.head()
# Out:
#                     name                     categories  \
# 0   Goa Food Truck (TCC)  Vegetarian / Vegan Restaurant
# 1               Fit Food                     Restaurant
# 2  Irashai Japanese Food               Sushi Restaurant
# 3           Quality Food           Brazilian Restaurant
# 4               Fit Food                     Restaurant
#
#                         address  cc       city country        crossStreet  \
# 0  Rua José Antônio Coelho, 879  BR  São Paulo  Brasil                NaN
# 1            Reebok Sports Club  BR  São Paulo  Brasil                NaN
# 2      R. Dr. Fausto Ferraz, 28  BR  São Paulo  Brasil  R. Carlos Sampaio
# 3       R. Peixoto Gomide, 1052  BR  São Paulo  Brasil                NaN
# 4                      Bodytech  BR  São Paulo  Brasil                NaN
#
#    distance                                   formattedAddress  \
# 0      1124  [Rua José Antônio Coelho, 879, São Paulo, SP, ...
# 1      2777  [Reebok Sports Club, São Paulo, SP, 04551-000,...
# 2      2778  [R. Dr. Fausto Ferraz, 28 (R. Carlos Sampaio),...
# 3      2918  [R. Peixoto Gomide, 1052, São Paulo, SP, 01409...
# 4      1994       [Bodytech, São Paulo, SP, 04542-000, Brasil]
#
#                                       labeledLatLngs        lat        lng  \
# 0  [{'label': 'display', 'lat': -23.58184, 'lng':... -23.581840 -46.649849
# 1  [{'label': 'display', 'lat': -23.5955329614596... -23.595533 -46.684341
# 2  [{'label': 'display', 'lat': -23.5663916712315... -23.566392 -46.645370
# 3  [{'label': 'display', 'lat': -23.5621563705620... -23.562156 -46.658713
# 4  [{'label': 'display', 'lat': -23.5874505404352... -23.587451 -46.677784
#
#   neighborhood postalCode state                        id  cluster
# 0          NaN        NaN    SP  54528c3f498ea48fc80daa59        2
# 1          NaN  04551-000    SP  4bf30cc1706e20a1fdc8a798        0
# 2   Bela Vista  01333-030    SP  4c548403b426ef3b53d8838a        4
# 3          NaN  01409-000    SP  4c3ca244933b0f470856e421        4
# 4          NaN  04542-000    SP  520ba1f711d2955c26da4960        0

# %% [markdown]
# Finaly, let's review the map, using different colors for each cluster.

# %%
venues_map = folium.Map(location=[lat, long], zoom_start=14) # generate map centred around Ibirapuera park

# add a red circle marker to represent Ibirapuera park
folium.vector_layers.CircleMarker(
    location = [lat, long],
    radius=10,
    color='red',
    fill = True,
    fill_color = 'red',
    fill_opacity = 0.6
).add_to(venues_map)

# add the venues as colorful circle markers
# each cluster will have its unique color so it can be identified
for lat, lng, label, cluster in zip(food_filtered.lat, food_filtered.lng, food_filtered.name, food_filtered.cluster):
    if cluster == 0:
        folium.vector_layers.CircleMarker(
            [lat, lng],
            radius=5,
            color='blue',
            fill = True,
            fill_color='blue',
            fill_opacity=0.6
        ).add_to(venues_map)
    elif cluster == 1:
        folium.vector_layers.CircleMarker(
            [lat, lng],
            radius=5,
            color='red',
            fill = True,
            fill_color='red',
            fill_opacity=0.6
        ).add_to(venues_map)
    elif cluster == 2:
        folium.vector_layers.CircleMarker(
            [lat, lng],
            radius=5,
            color='purple',
            fill = True,
            fill_color='purple',
            fill_opacity=0.6
        ).add_to(venues_map)
    elif cluster == 3:
        folium.vector_layers.CircleMarker(
            [lat, lng],
            radius=5,
            color='green',
            fill = True,
            fill_color='green',
            fill_opacity=0.6
        ).add_to(venues_map)
    elif cluster == 4:
        folium.vector_layers.CircleMarker(
            [lat, lng],
            radius=5,
            color='orange',
            fill = True,
            fill_color='orange',
            fill_opacity=0.6
        ).add_to(venues_map)
    elif cluster == 5:
        folium.vector_layers.CircleMarker(
            [lat, lng],
            radius=5,
            color='pink',
            fill = True,
            fill_color='pink',
            fill_opacity=0.6
        ).add_to(venues_map)
    elif cluster == 6:
        folium.vector_layers.CircleMarker(
            [lat, lng],
            radius=5,
            color='gray',
            fill = True,
            fill_color='gray',
            fill_opacity=0.6
        ).add_to(venues_map)
    else:
        folium.vector_layers.CircleMarker(
            [lat, lng],
            radius=5,
            color='black',
            fill = True,
            fill_color='black',
            fill_opacity=0.6
        ).add_to(venues_map)
        

# display map
display(venues_map)
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# We can see that the purple cluster is the closest to the park and has several venues within it.
#
# We can also see that, between the park and the blue cluster there are several block with no food venues. The same goes the red cluster.
#
# Therefore, the West and South regions of the park would be good regions for the new restaurant, specially because their closer to the República do Líbano Avenue and Quarto Centenário Avenue.

# %% [markdown]
# Let's investigate both cluster to see which food options they provide.

# %% [markdown]
# 10. Exploring the red and blue clusters.

# %%
#Displaying the blue cluster
food_filtered.loc[food_filtered['cluster'] == 0,:]
# Out:
#                            name             categories  \
# 1                      Fit Food             Restaurant
# 4                      Fit Food             Restaurant
# 6        Vila Olímpia Food Hall  Street Food Gathering
# 18       Shigueru Japanese Food    Japanese Restaurant
# 19  Hale I'a Hawaiian Fish Food    Hawaiian Restaurant
# 35       Kebebariak Casual Food     Falafel Restaurant
#
#                                        address  cc       city country  \
# 1                           Reebok Sports Club  BR  São Paulo  Brasil
# 4                                     Bodytech  BR  São Paulo  Brasil
# 6                              R. Tenerife, 74  BR  São Paulo  Brasil
# 18  R. Leopoldo Couto de Magalhaes Júnior, 275  BR  São Paulo  Brasil
# 19              R. Prof. Atílio Innocenti, 693  BR  São Paulo  Brasil
# 35                                         NaN  BR        NaN  Brasil
#
#    crossStreet  distance                                   formattedAddress  \
# 1          NaN      2777  [Reebok Sports Club, São Paulo, SP, 04551-000,...
# 4          NaN      1994       [Bodytech, São Paulo, SP, 04542-000, Brasil]
# 6          NaN      3191  [R. Tenerife, 74, São Paulo, SP, 04548-040, Br...
# 18         NaN      1777  [R. Leopoldo Couto de Magalhaes Júnior, 275, S...
# 19         NaN      2236  [R. Prof. Atílio Innocenti, 693, São Paulo, SP...
# 35         NaN      1461                                           [Brasil]
#
#                                        labeledLatLngs        lat        lng  \
# 1   [{'label': 'display', 'lat': -23.5955329614596... -23.595533 -46.684341
# 4   [{'label': 'display', 'lat': -23.5874505404352... -23.587451 -46.677784
# 6   [{'label': 'display', 'lat': -23.596512, 'lng'... -23.596512 -46.688254
# 18  [{'label': 'display', 'lat': -23.5869510955304... -23.586951 -46.675610
# 19  [{'label': 'display', 'lat': -23.5937617201006... -23.593762 -46.679374
# 35  [{'label': 'display', 'lat': -23.584044, 'lng'... -23.584044 -46.671783
#
#    neighborhood postalCode state                        id  cluster
# 1           NaN  04551-000    SP  4bf30cc1706e20a1fdc8a798        0
# 4           NaN  04542-000    SP  520ba1f711d2955c26da4960        0
# 6           NaN  04548-040    SP  59a9aa63d8fe7a0d1368ee55        0
# 18          NaN        NaN    SP  4d49cbf59544a0934a432ce7        0
# 19          NaN  04538-001    SP  5acdf3c56fa81f479105ddf4        0
# 35          NaN        NaN   NaN  5058ae4de4b02049c1ed7626        0

# %%
#Displaying the red cluster
food_filtered.loc[food_filtered['cluster'] == 1,:]
# Out:
#                                          name            categories  \
# 10  NaturALL Fit - Healthy Food & Supplements     Food & Drink Shop
# 36                               Food Trucker  Fast Food Restaurant
#
#                   address  cc       city country crossStreet  distance  \
# 10        240 Rua Urussuí  BR  São Paulo  Brasil         NaN      2575
# 36  Rua Dr. Bacelar, 1043  BR  São Paulo  Brasil         NaN      2000
#
#                                      formattedAddress  \
# 10  [240 Rua Urussuí, São Paulo, SP, 04542-051, Br...
# 36     [Rua Dr. Bacelar, 1043, São Paulo, SP, Brasil]
#
#                                        labeledLatLngs        lat        lng  \
# 10  [{'label': 'display', 'lat': -23.604378, 'lng'... -23.604378 -46.640018
# 36  [{'label': 'display', 'lat': -23.6038580540477... -23.603858 -46.648309
#
#    neighborhood postalCode state                        id  cluster
# 10          NaN  04542-051    SP  591b62a4b9ac384466c171c7        1
# 36          NaN        NaN    SP  543306ca498e1a4f90a35455        1

# %% [markdown]
# Considering that our investor has experience with Japanese, vegetarian and Italian food; if he chooses to stay in the South, a Japanese or Italian restaurants would be good options, if he chooses to stay in the West, the best choice would be an Italian restaurant.

# %% [markdown]
# # Summary of the results and discussion
#
# After performing the cluster analysis, two regions next to the park didn’t have any food venues, South and West. Both regions would be good locations, not only because they don’t have any food venues, but also because they are close to two avenues that would make the access easier, Quarto Centenário Avenue in the South, and República do Líbano Avenue on the West.
#
# Since there are two good option, both were evaluated. On the West, the next cluster is the blue cluster. In the blue cluster, we have one Japanese restaurant and two restaurants called fit food, which might provide vegetarian options. Therefore, if the investor chooses to stay in the West, the option would be an Italian restaurant.
# In the South, we have just two venues, food truck and a venue called NatuALL fit, which most likely have vegetarian options. Therefore, both Italian and Japanese restaurants would be good options, if the investor chooses to stay in the South region.

# %% [markdown]
# # Conclusion
#
# The West and South regions of the park presented no competition for several block, therefore, the recomended places to start the restaurant would be close to the República do Líbano Avenue and Quarto Centenário Avenue, not only because they are close to such regions, but will also provide easy access to the restaurant.
#
# The two closest clusters (red and blue) didn't have any Italian nor vegetarian restaurants, so if the investor opens one of this two types of restaurant, he will not only be in a region with low competition, but he will also differenciate himself from the closest options.
